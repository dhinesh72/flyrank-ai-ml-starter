# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dhinesh72/flyrank-ai-ml-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### My lane: CTR / Engagement Opportunity Scoring
#
# I chose the CTR / Engagement Opportunity Scoring lane because I want to understand which visible pages receive fewer clicks or weaker engagement than expected. In my Week-1 exploration, I found a very weak negative relationship between average position and CTR (correlation -0.073). This made me interested in studying CTR more carefully while considering search position. The goal is to create a useful ranking of pages that may deserve review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### My research question
#
# Can we rank visible pages that appear to have lower-than-expected CTR and may deserve review? The decision is which pages should be prioritized for CTR or content review. An SEO or content team member would act on the ranking by reviewing the highest-priority pages. A false positive mainly costs review time and effort, while a false negative could cause a page with a potential CTR opportunity to be missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Quick look at the data
#
# The dataset contains 30,000 pages, and all 30,000 pages have impressions in the 90-day period used here. Among visible pages, the median CTR is 0.070 and the median average position is 10.8. These numbers make CTR opportunity scoring worth investigating because there is enough page-level data to compare CTR and search position and prioritize pages for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import subprocess
import sys
import pandas as pd

REPO_DIR = "/content/flyrank-ai-ml-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(
        ["git", "clone", "--depth", "1",
         "https://github.com/dhinesh72/flyrank-ai-ml-starter",
         REPO_DIR],
        check=True
    )

os.chdir(REPO_DIR)

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

visible = df[df["impressions_90d"] > 0]

print("Total pages:", len(df))
print("Visible pages:", len(visible))
print("Median CTR among visible pages:", round(visible["ctr"].median(), 3))
print("Median average position among visible pages:", round(visible["avg_position"].median(), 2))
# Out:
# Total pages: 30000
# Visible pages: 30000
# Median CTR among visible pages: 0.07
# Median average position among visible pages: 10.8

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### Careful words
#
# This work can provide observed and directional evidence about which visible pages may have CTR opportunities. The results can be used as decision-support to help prioritize pages for review. It cannot prove that one factor causes CTR to change, and it cannot claim to predict or explain Google's algorithm. Any recommendations will be treated as measured signals from this dataset, not causal conclusions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
